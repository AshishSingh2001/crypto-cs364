# %%
EllipticCurve([25,31]).plot(xmin=-10, xmax=13, ymin=-13, ymax=13)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
EllipticCurve(GF(101),[25,31]).plot(xmin=-2, xmax=101, ymin=-2, ymax=101)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
ctr = 0
for i in range(0,101):
    for j in range(0,101):
        x = ((i*i*i) + (25*i) + 31) % 101
        y = (j*j)%101
        if(x == y):
            # print(i,j)
            ctr = ctr + 1

print(ctr)
# Out:
# 91
